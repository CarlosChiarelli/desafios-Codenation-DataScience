# %% [markdown]
# # Desafio 02

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from seaborn import heatmap
import funcoesProprias as fp

# %%
fp.configuraJupyter()

# %%
# importando dados
df = pd.read_csv('desafio1.csv')

# %%
df.head()
# Out:
#    RowNumber                                        id  \
# 0          1  e7f44fcbd380d4cef7e6c232cc7e37895c3fd197
# 1          2  28dcb083ad90512da16b9430085c2cddb8ca5e12
# 2          3  774bc378f787438c9c7594e536787d07a097a54b
# 3          4  043a71326f7096de155e7f0c559dc62b5e4b7239
# 4          5  37b3bb8ca243955fb3605ec7e1c2a4607cdb3b22
#
#                                   sobrenome  pontuacao_credito  \
# 0  6d6e0aa1b9b413e442e2fb68df14b4fc3f91de50                619
# 1  48e1ad846796fa314f1b4a6702b83343eb5482c5                608
# 2  f2b29d5d934de615812b697132e767dea0f1e9e2                502
# 3  85d5c9da7cddd8109ad32a6c348fe2bb10bf99f2                699
# 4  ddc89c837a6933639de75f28171057060bd322df                850
#
#   estado_residencia genero  idade  nivel_estabilidade  saldo_conta  \
# 0                SC      F     42                   2         0.00
# 1                RS      F     41                   1     83807.86
# ...

# %%
explora = fp.dfExploracao(df)
explora.sort_values('tipos')
# Out:
#                      colunas    tipos  na_perct  quantUnicos
# 0                  RowNumber    int64       0.0         7000
# 3          pontuacao_credito    int64       0.0          451
# 6                      idade    int64       0.0           69
# 7         nivel_estabilidade    int64       0.0           11
# 9            numero_produtos    int64       0.0            4
# 10  possui_cartao_de_credito    int64       0.0            2
# 11              membro_ativo    int64       0.0            2
# 8                saldo_conta  float64       0.0         4468
# 1                         id   object       0.0         7000
# 2                  sobrenome   object       0.0         2448
# 4          estado_residencia   object       0.0            3
# 5                     genero   object       0.0            2

# %%
colsNum = explora[explora.tipos != 'object'].colunas
colsCarac = explora[explora.tipos == 'object'].colunas

# %%
df.describe()
# Out:
#          RowNumber  pontuacao_credito        idade  nivel_estabilidade  \
# count  7000.000000        7000.000000  7000.000000         7000.000000
# mean   3500.500000         649.787000    38.892714            5.010286
# std    2020.870275          97.046279    10.465562            2.887500
# min       1.000000         350.000000    18.000000            0.000000
# 25%    1750.750000         582.000000    32.000000            3.000000
# 50%    3500.500000         651.000000    37.000000            5.000000
# 75%    5250.250000         717.000000    44.000000            7.250000
# max    7000.000000         850.000000    92.000000           10.000000
#
#          saldo_conta  numero_produtos  possui_cartao_de_credito  membro_ativo
# count    7000.000000      7000.000000               7000.000000   7000.000000
# mean    76471.883751         1.526000                  0.703286      0.512143
# std     62403.383911         0.583047                  0.456842      0.499888
# ...

# %%
aux = df[colsNum]
aux = aux.drop('RowNumber', axis=1)
fp.plotNumVsNum(aux)
# Out:
# TODAS COLUNAS NUMÉRICAS

# %%
fp.plotNumVsNumReg(aux)
# Out:
# COLUNAS NUMERICAS - REGRESSÃO

# %%
heatmap(aux.corr(), annot=True)

# %%
aux = df[colsCarac]
aux = aux.drop(['id','sobrenome'], axis=1)
fp.plotObjCols(aux)
# Out:
# c:\users\jardi\appdata\local\programs\python\python37\lib\site-packages\funcoesProprias\visualizacao.py:36: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# CONTAGEM DAS COLUNAS OBJECT

# %% [markdown]
# ## Lendo JSON

# %%
json = pd.read_json('submissionOriginal.json')

# %%
json.head()
# Out:
#                SC  RS  PR
# moda            0   0   0
# mediana         0   0   0
# media           0   0   0
# desvio_padrao   0   0   0

# %%
df.head()
# Out:
#    RowNumber                                        id  \
# 0          1  e7f44fcbd380d4cef7e6c232cc7e37895c3fd197
# 1          2  28dcb083ad90512da16b9430085c2cddb8ca5e12
# 2          3  774bc378f787438c9c7594e536787d07a097a54b
# 3          4  043a71326f7096de155e7f0c559dc62b5e4b7239
# 4          5  37b3bb8ca243955fb3605ec7e1c2a4607cdb3b22
#
#                                   sobrenome  pontuacao_credito  \
# 0  6d6e0aa1b9b413e442e2fb68df14b4fc3f91de50                619
# 1  48e1ad846796fa314f1b4a6702b83343eb5482c5                608
# 2  f2b29d5d934de615812b697132e767dea0f1e9e2                502
# 3  85d5c9da7cddd8109ad32a6c348fe2bb10bf99f2                699
# 4  ddc89c837a6933639de75f28171057060bd322df                850
#
#   estado_residencia genero  idade  nivel_estabilidade  saldo_conta  \
# 0                SC      F     42                   2         0.00
# 1                RS      F     41                   1     83807.86
# ...

# %%
dfEstat = df.groupby('estado_residencia').agg(
    {'pontuacao_credito':[pd.Series.mode,'median','mean','std']}
).transpose().reset_index()

dfEstat = dfEstat[['level_1','SC','RS','PR']]
#dfEstat = dfEstat.transpose()
dfEstat
# Out:
# estado_residencia level_1          SC          RS          PR
# 0                    mode  850.000000  850.000000  850.000000
# 1                  median  653.000000  650.000000  650.000000
# 2                    mean  649.537653  651.105143  648.961294
# 3                     std   97.233493   95.136598   98.607186

# %%
dfFinal = dfEstat.copy()
dfFinal['estat'] = ['moda','mediana','media','desvio_padrao']
dfFinal.set_index('estat', inplace=True)
dfFinal = dfFinal[['SC','RS','PR']]
dfFinal
# Out:
# estado_residencia          SC          RS          PR
# estat
# moda               850.000000  850.000000  850.000000
# mediana            653.000000  650.000000  650.000000
# media              649.537653  651.105143  648.961294
# desvio_padrao       97.233493   95.136598   98.607186

# %%
dfFinal.to_json('submission.json')
